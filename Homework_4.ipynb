# %% [markdown]
# Use the Machine Learning algorithms Decision Tree and Random Forest and the DB_Voice_Features.csv database to discriminate and evaluate classification performance of healthy and PD patients by voice signal features.
#
# For each case use:
# *   Parameter Optimization
# *   Solve the Imbalance Problem
# *   Discuss the results obtained (different metrics)
# Due date: 10/24/2023

# %% [markdown]
# # Decision Tree

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

Parkinsons_data = pd.read_csv('DB_Voice_Features.csv')
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
Parkinsons_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
Parkinsons_data.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
plt.scatter(Parkinsons_data['MDVP:Fhi(Hz)'], Parkinsons_data['MDVP:Flo(Hz)'], Parkinsons_data ['MDVP:Fo(Hz)'])
plt.show()

# %%
sns.set_style('whitegrid')
sns.FacetGrid(Parkinsons_data, hue = 'Data') \
   .map(plt.scatter, 'SepalLengthCm','SepalWidthCm') \
   .add_legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/sebas/Documents/Parkinson-s-Disease-Detection---ML/Homework_4.ipynb Cell 7 line 2
#       <a href='vscode-notebook-cell:/Users/sebas/Documents/Parkinson-s-Disease-Detection---ML/Homework_4.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> sns.set_style('whitegrid')
# ----> <a href='vscode-notebook-cell:/Users/sebas/Documents/Parkinson-s-Disease-Detection---ML/Homework_4.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> sns.FacetGrid(Iris_data, hue = '') \
#       <a href='vscode-notebook-cell:/Users/sebas/Documents/Parkinson-s-Disease-Detection---ML/Homework_4.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a>    .map(plt.scatter, 'SepalLengthCm','SepalWidthCm') \
#       <a href='vscode-notebook-cell:/Users/sebas/Documents/Parkinson-s-Disease-Detection---ML/Homework_4.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a>    .add_legend()
# ...
